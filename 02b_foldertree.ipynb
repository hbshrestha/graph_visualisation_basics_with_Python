# %% [markdown]
# https://www.youtube.com/watch?v=SpDI6-FvtJY

# %% [markdown]
# ### Directory structure plotter

# %%
import pydot
import os

#Return current working directory
rootDir = os.getcwd()

# %%
G = pydot.Dot(graph_type = "digraph")

# %%
currentDir = rootDir.split("/")[-1]
currentDir
# Out:
# 'graph_visualisation_basics'

# %%
node = pydot.Node(currentDir, style = "filled", fillcolor = "green")
G.add_node(node)

# %%
for root, dirs, files in os.walk(rootDir):
    print (root)
# Out:
# /Users/himalaya.birshrestha/Desktop/Private/graph_visualisation_basics
# /Users/himalaya.birshrestha/Desktop/Private/graph_visualisation_basics/output
# /Users/himalaya.birshrestha/Desktop/Private/graph_visualisation_basics/.ipynb_checkpoints
# /Users/himalaya.birshrestha/Desktop/Private/graph_visualisation_basics/.git
# /Users/himalaya.birshrestha/Desktop/Private/graph_visualisation_basics/.git/objects
# /Users/himalaya.birshrestha/Desktop/Private/graph_visualisation_basics/.git/objects/pack
# /Users/himalaya.birshrestha/Desktop/Private/graph_visualisation_basics/.git/objects/info
# /Users/himalaya.birshrestha/Desktop/Private/graph_visualisation_basics/.git/info
# /Users/himalaya.birshrestha/Desktop/Private/graph_visualisation_basics/.git/logs
# /Users/himalaya.birshrestha/Desktop/Private/graph_visualisation_basics/.git/logs/refs
# /Users/himalaya.birshrestha/Desktop/Private/graph_visualisation_basics/.git/logs/refs/heads
# /Users/himalaya.birshrestha/Desktop/Private/graph_visualisation_basics/.git/logs/refs/remotes
# /Users/himalaya.birshrestha/Desktop/Private/graph_visualisation_basics/.git/logs/refs/remotes/origin
# /Users/himalaya.birshrestha/Desktop/Private/graph_visualisation_basics/.git/hooks
# /Users/himalaya.birshrestha/Desktop/Private/graph_visualisation_basics/.git/refs
# /Users/himalaya.birshrestha/Desktop/Private/graph_visualisation_basics/.git/refs/heads
# /Users/himalaya.birshrestha/Desktop/Private/graph_visualisation_basics/.git/refs/tags
# /Users/himalaya.birshrestha/Desktop/Private/graph_visualisation_basics/.git/refs/remotes
# /Users/himalaya.birshrestha/Desktop/Private/graph_visualisation_basics/.git/refs/remotes/origin

# %%
for root, dirs, files in os.walk(rootDir):
    
    #Ignore hidden files
    if root==rootDir or (root.split("/")[6].startswith(".") == False):
        print (root)
# Out:
# /Users/himalaya.birshrestha/Desktop/Private/graph_visualisation_basics
# /Users/himalaya.birshrestha/Desktop/Private/graph_visualisation_basics/output

# %%
for root, dirs, files in os.walk(rootDir):
    
    #Ignore hidden files and folder
    if root==rootDir or (root.split("/")[6].startswith(".") == False):
       
        for subdir in dirs:
            if subdir.startswith(".") == False:
                node = pydot.Node(subdir, style = "filled", fillcolor = "yellow")

                G.add_node(node)

                edge = pydot.Edge(root.split("/")[-1], subdir)
                G.add_edge(edge)
        
        for file in files:
            node = pydot.Node(file, style = "filled", fillcolor = "orange")
            G.add_node(node)

            edge = pydot.Edge(root.split("/")[-1], file)
            G.add_edge(edge)

# %%
from IPython.display import Image, display


im = Image(G.create_png())
display(im)

# %%
G.write_jpeg("output/folder_tree.jpeg")

# %%
G.write_png("output/folder_tree.png")

# %%
import pydot
import os
from IPython.display import Image, display

#Return current working directory including the path
rootDir = os.getcwd()

#Create a graph object of directed type
G = pydot.Dot(graph_type = "digraph")

#Get the name of the current directory only
currentDir = rootDir.split("/")[-1]

#Add a node named after current directory filled with green color
node = pydot.Node(currentDir, style = "filled", fillcolor = "green")
G.add_node(node)

#Loop through the directory, subdirectory and files of root directory
for root, dirs, files in os.walk(rootDir):
    
    #Ignore hidden files and folder
    if root==rootDir or (root.split("/")[6].startswith(".") == False):
       
        for subdir in dirs:
            
            #Ignore hidden folder
            if subdir.startswith(".") == False:
                
                #Add nodes with name of subdirectory and fill it with yellow color
                node = pydot.Node(subdir, style = "filled", fillcolor = "yellow")
                G.add_node(node)

                #Add the edge between root directory and sub directory
                edge = pydot.Edge(root.split("/")[-1], subdir)
                G.add_edge(edge)
        
        for file in files:
            
            #Add node for each file and fill it with orange color
            node = pydot.Node(file, style = "filled", fillcolor = "orange")
            G.add_node(node)

            #Add edge between directory/subdirectory and file 
            edge = pydot.Edge(root.split("/")[-1], file)
            G.add_edge(edge)

#Create the image of folder tree
im = Image(G.create_jpeg())

#Display the image
display(im)

#Save the image in jpeg format
G.write_jpeg("output/folder_tree.jpeg")

# %%
IPython.display.display(Image(G.create_jpeg()))

# %%
rootDir
